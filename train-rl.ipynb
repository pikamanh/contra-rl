# %%
# !apt-get update -y
# !apt-get install -y python3.10-distutils python3.10-venv
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:8 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,765 kB]
# Get:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# ...

# %%
# !rm -rf venv
# !python3.10 -m venv venv
# !/kaggle/working/venv/bin/python --version
# Out:
# Python 3.10.12

# %%
# !/kaggle/working/venv/bin/python -m ensurepip --upgrade
# !/kaggle/working/venv/bin/python -m pip install --upgrade "pip<24" setuptools wheel
# Out:
# Looking in links: /tmp/tmpwlial534
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 28.3 MB/s eta 0:00:0000:010:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 65.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 KB 14.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 68.1.2
#     Uninstalling setuptools-68.1.2:
#       Successfully uninstalled setuptools-68.1.2
#   Attempting uninstall: pip
#     Found existing installation: pip 22.0.2
#     Uninstalling pip-22.0.2:
#       Successfully uninstalled pip-22.0.2
# ...

# %%
import os
os.cpu_count()

# %%
# !git clone https://github.com/pikamanh/contra-rl.git
# Out:
# Cloning into 'contra-rl'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 33 (delta 0), reused 30 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 444.05 KiB | 15.31 MiB/s, done.

# %%
# gym==0.21.0 requires setuptools<66 to build (uses legacy setup.py egg_info)
# Temporarily downgrade → install gym → restore
# !/kaggle/working/venv/bin/python -m pip install -q "setuptools==65.5.0"
# !/kaggle/working/venv/bin/python -m pip install "gym==0.21.0"
# !/kaggle/working/venv/bin/python -m pip install -q "setuptools>=67"
# !/kaggle/working/venv/bin/python -m pip install -r /kaggle/working/contra-rl/requirements_rl.txt

# %%
# !python3 /kaggle/working/RL-Fireboy-Watergirl/rl/train.py --all-levels --sampling curriculum --steps 10000000 --n-envs 8 --max-steps 3000
# !/kaggle/working/venv/bin/python /kaggle/working/contra-rl/train.py \
  --action-set simple \   # simple / complex / right
  --n-envs 4 \            # số env song song
  --total-timesteps 10 \
  --save-freq-epochs 25 \ # checkpoint mỗi 25 epochs
  --save-dir models \
  --zip                   # tạo archive .zip mỗi checkpoint

# %%
# !/kaggle/working/venv/bin/python /kaggle/working/contra-rl/eval.py \
--model-path models/best/best_model.zip
